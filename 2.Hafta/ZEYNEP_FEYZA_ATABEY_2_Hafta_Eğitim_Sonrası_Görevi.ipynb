# %% [markdown]
# # 2. Hafta Eğitim Sonrası Görevi
#
# Merhaba sevgili YetGenli 🥰
#
# Seninle çok güzel bir eğitimin sonuna geldik 🤓 Umarız senin için bol öğretici ve bir o kadar da eğlenceli bir eğitim olmuştur 🥳
#
# Şimdiyse sıra 2. Hafta eğitim sonrası görevimizde!
#
# Senden görevimizde aşağıdaki 8 problememiz için uygun birer program geliştirmeni bekliyoruz.

# %% [markdown]
# # Problem 1

# %% [markdown]
# ![compound.png](data:image/png;base64,...)

# %% [markdown]
# Yukarıda bileşik faizin hesaplanması ve bu hesaplamaya ait elementlerin açıklamaları verilmiştir.
#
# Kullanıcıdan ilk olarak ad, soyad, yaş ve meslek bilgilerini input (girdi) olarak alınız. Daha sonra principal amount (ana para), rate (faiz oranı) ve time (zamanı yıl olarak) kullanıcıdan input (girdi) alarak bunun sonucunda bileşik faizi hesaplayınız.
#
# Son olarak kullanıcıya:
#
# `“Merhaba A (isim) B (soyad), C (yaşındasınız) ve D mesleğini yapmaktasınız. P (ana para) TL’nin R (faiz oranı) oranı ile  T (yıllık)  bileşik faizi C (bileşik faizi miktarı)’dir” `
#
# Şeklinde bir çıktı veren bir program yazınız.

# %%
# 1. problemimiz için kodlarını buraya yazabilirsin.

A = input("İsminizi Giriniz ")
B = input("Soyadınızı Giriniz ")
C = input("Yaşınızı Giriniz ")
D = input("Mesleğinizi Giriniz ")
P = int (input("Ana paranızı Giriniz "))
R = float (input("Yıllık faiz oranını Giriniz "))
T = int (input("Zamanı Giriniz "))
h = P*(1 + R/100)
c = P*pow((1+R/100),T)
d = c-P 
d = round(d,2)

print(f"Merhaba {A} {B} , {C} yaşındasınız ve {D} mesleğini yapmaktasınız. {P} ₺’nin {R} faiz oranı ile {T} yıllık  bileşik faizin getirisi {d} bileşik faizi miktarı’dir")
# Out:
# İsminizi Giriniz Feyza
# Soyadınızı Giriniz Atabey
# Yaşınızı Giriniz 23
# Mesleğinizi Giriniz öğrenci
# Ana paranızı Giriniz 1000
# Yıllık faiz oranını Giriniz 2
# Zamanı Giriniz 2
# Merhaba Feyza Atabey , 23 yaşındasınız ve öğrenci mesleğini yapmaktasınız. 1000 ₺’nin 2.0 faiz oranı ile 2 yıllık  bileşik faizin getirisi 40.4 bileşik faizi miktarı’dir

# %% [markdown]
# # Problem 2

# %% [markdown]
# ![silindir-koni-hacim.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Kullanıcıdan taban yarıçapı ve yükseklik bilgisini alarak silindirin hacmini ve bundan yola çıkarak da koninin hacmini hesaplayınız. Pi sayısını 3.14 olarak sabit giriniz. Daha sonra yukarıdaki problemde olduğu gibi kullanıcıya bilgi veren bir program yazınız.
#
# Örnek:
#
# `”5 cm yarıçaplı 12 cm yüksekliğindeki silindirin hacmi X ve koninin hacmi Y dir.” `
#
# Şeklinde.

# %%
# 2. problemimiz için kodlarını buraya yazabilirsin.

yarıcap = float(input("Taban yarıçapını giriniz (cm) "))
yukseklik = float(input("Yüksekliğini giriniz (cm) "))

pi = 3.14

silindir_hacim = pi *(yarıcap**2)*yukseklik
koni_hacim = silindir_hacim/3

print("{} cm yarıçaplu ve {} cm yüksekliğindeki silindirin hacmi {} santimetre küptür ve koninin hacmi {} sanimetre küptür.".format(yarıcap,yukseklik,silindir_hacim,koni_hacim))

#Aşağıda her ikisi için de ayrı yarıçap ve yükseklik değeri almıştım.

R_silindir = input("Silindirin yarıçapını giriniz (cm)  ")
H_silindir = input("Silindirin yüksekliğini giriniz (cm) ")

H_koni = input("Koninin yüksekliğini giriniz ")
R_koni = input("Koninin yarıçapını giriniz ")

pi = 3.14

V_silindir = int(pi)*int(R_silindir)*int(H_silindir)
V_koni = 1/3*int(pi)*int(R_koni)**2*int(H_koni)

print( "{} ".format(R_koni) + "cm yarıçaplı " "{}".format(H_koni) + "cm yüksekliğindeki koninin hacmi cm**3'dür" + " {}".format(V_koni) )
print(f"{R_silindir} cm yarıçaplı {H_silindir} cm yüksekliğindeki siindirin hacmi  {V_silindir} ve koninin hacmi {V_koni} santimetre küptür.")
# Out:
# Taban yarıçapını giriniz (cm) 3
# Yüksekliğini giriniz (cm) 4
# 3.0 cm yarıçaplu ve 4.0 cm yüksekliğindeki silindirin hacmi 113.04 santimetre küptür ve koninin hacmi 37.68 sanimetre küptür.
# Silindirin yarıçapını giriniz (cm)  5
# Silindirin yüksekliğini giriniz (cm) 6
# Koninin yüksekliğini giriniz 3
# Koninin yarıçapını giriniz 5
# 5 cm yarıçaplı 3cm yüksekliğindeki koninin hacmi cm**3'dür 75.0
# 5 cm yarıçaplı 6 cm yüksekliğindeki siindirin hacmi  90 ve koninin hacmi 75.0 santimetre küptür.

# %% [markdown]
# # Problem 3

# %% [markdown]
# Kullanıcıdan 2 adet sayı alınız. Geçici (temp) bir değişken yardımı ile bu sayıları birbirleri ile değiştirin bir program yazınız.
#
# Örnek: a = 3, b = 5 işlemden sonra **a = 5, b = 3**.

# %%
# 3. problemimiz için kodlarını buraya yazabilirsin.


a = input("Bir sayı giriniz ")
b = input("Bir sayı giriniz ")

temp = a
a = b
b = temp

print(a,b)
# Out:
# Bir sayı giriniz 3
# Bir sayı giriniz 4
# 4 3

# %% [markdown]
# # Problem 4

# %% [markdown]
# 4 adet değişken tanımlayınız. Bunlar sırasıyla `int, float, complex ve boolean` ifadeler olsun.
#
# Tüm bu değişkenleri ve tiplerini ekrana bastırınız. Daha sonrasında hepsinin tiplerini `stringe` çeviren ve tekrar ekrana bastıran bir program yazınız.
#
# İpucu: Veri tiplerini yazdırmak için `type()` fonksiyonunu kullanabilirsin

# %%
# 4. problemimiz için kodlarını buraya yazabilirsin.

a = 4
b = 4.4
c = 1 + 4j
d = True

print(type(a))         
print(type(b))         
print(type(c))      
print(type(d))

a = str(a)
b = str(b)
c = str(c)
d = str(d)

print(a,b,c,d)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'bool'>
# 4 4.4 (1+4j) True

# %% [markdown]
# # Problem 5

# %% [markdown]
# Dikdörtgenin iki kenar uzunluğunu kullanıcıya sorup, dikdörtgenin çevresini ve alanını hesaplayan bir program yazınız
#
# İpucu: Kenar uzunluklarını input ile alabilirsiniz.
#
# **Örnek**
#
# ```
# >>>input:
# 6 , 4
#
# >>>output:
# Çevre: 20
# Alan: 24
# ```

# %% [markdown]
# ![dikdortgen-cevre-alan.jpg](data:image/jpeg;base64,...)

# %%
# 5. problemimiz için kodlarını buraya yazabilirsin.

x = int (input ("Dikdörtgenin kısa kenarının uzunluğunu giriniz "))
y = int (input ( "Dikdörtgenin uzun kenarının uzunluğunu giriniz "))

Cevre = 2*(x+y)
Alan = x*y

print("Dikdörtgenin çevresi {} cm ve alanı da {} santimetre karedir.".format(Cevre,Alan))
# Out:
# Dikdörtgenin kısa kenarının uzunluğunu giriniz 4
# Dikdörtgenin uzun kenarının uzunluğunu giriniz 5
# Dikdörtgenin çevresi 18 cm ve alanı da 20 santimetre karedir.

# %% [markdown]
# # Problem 6

# %% [markdown]
# Sen ve YetGen ekibin bir restorana gidiyorsunuz. Garson size iyi davranıyor, bu yüzden ona bahşiş vermeye karar veriyorsunuz. Gelen hesap üzerinden %12 oranında bahşiş bırakmak ve hesabı eşit olarak bölüşmek istiyorsunuz. Kişi başı ne kadar hesap ödemeniz gerekir?
#
# İpucu: Kişi sayısı, fatura ve bahşiş oranını input ile alabilirsiniz.
#
# ![image.png](data:image/png;base64,...)
#
# **Örnek**
# ```
# >>>input
# 150
# 12
# 5
# >>>output
# 33.6
# ```

# %%
# 6. problemimiz için kodlarını buraya yazabilirsin.

print("Hoş geldiniz YetGen Ekibi bahşiş hesaplayıcı size yardımcı olmak için hazırdır.\n Lütfen değerleri doğru ve giriniz\n Afiyet olsun!\n")

hesap = float(input("Hesap tutarınızı giriniz "))
bahsis = int(input("Yüzde kaç bahşiş olarak vermek istiyorsunuz "))
kisi_sayısı = int(input("Kaç kişisiniz giriniz "))

bahsis_yuzdesi = bahsis/100
toplam_bahsis = hesap*bahsis_yuzdesi

odenecek_tutar = hesap+toplam_bahsis
kisi_bası_tutar = odenecek_tutar/kisi_sayısı

yuvarlanmıs_tutar = round(kisi_bası_tutar,2)

print("Kişi başı ödeyeceğiniz tutar",yuvarlanmıs_tutar,"TL")
# Out:
# Hoş geldiniz YetGen Ekibi bahşiş hesaplayıcı size yardımcı olmak için hazırdır.
#  Lütfen değerleri doğru ve giriniz
#  Afiyet olsun!
#
# Hesap tutarınızı giriniz 120
# Yüzde kaç bahşiş olarak vermek istiyorsunuz 12
# Kaç kişisiniz giriniz 21
# Kişi başı ödeyeceğiniz tutar 6.4 TL

# %% [markdown]
# # Problem 7

# %% [markdown]
# Fantasya'da;
#
# Her 7 saniyede bir doğum gerçekleşiyor.
#
# Her 13 saniyede bir ölüm meydana geliyor.
#
# Her 45 saniyede bir göç alınıyor.
#
# Önümüzdeki 5 yıl sonraki popülasyonu hesaplamak için bir program yazın. Şu anki Fantasya nüfusunun 3.000.000 kişi, 1 yılda 365 gün olduğunu varsayın.
#
# İpucu : Pythonda bölme işlemi için tam sayı bölme operatörünü (//) kullanabilirsiniz. Örneğin; 5//4=1 (1.25 değil), 10//4=2 (2.5 değil)

# %%
# 7. problemimiz için kodlarını buraya yazabilirsin.

print("Popülasyon hesap aracına hoş geldiniz!\n")
ulke_adı = input("Ülkenin adını giriniz ")
nufus = int(input("Şu anki nüfusu giriniz "))
yıl_sayısı = int(input("Kaç yıl sonraki popülasyonu hesaplamak istediğinizi giriniz "))
saniye = yıl_sayısı*365*24*60*60

saniyede_dogum = int(input("Ülkenin her saniyede gerçekleşen doğum sayısını giriniz "))
saniyede_olum = int(input("Ülkenin her saniyede gerçekleşen olum sayısını giriniz "))
saniyede_goc_alımı = int(input("Ülkenin her saniyede aldığı göçü giriniz "))

dogum = saniye//saniyede_dogum
olum = saniye//saniyede_olum
goc_alımı = saniye//saniyede_goc_alımı

son_populasyon = nufus+dogum+goc_alımı-olum
print(ulke_adı, "ülkesinin son nüfusu", son_populasyon ,"kişidir.")
# Out:
# Popülasyon hesap aracına hoş geldiniz!
#
# Ülkenin adını giriniz Fantasya
# Şu anki nüfusu giriniz 3000000
# Kaç yıl sonraki popülasyonu hesaplamak istediğinizi giriniz 5
# Ülkenin her saniyede gerçekleşen doğum sayısını giriniz 7
# Ülkenin her saniyede gerçekleşen olum sayısını giriniz 13
# Ülkenin her saniyede aldığı göçü giriniz 45
# Fantasya Ülkenin son nüfusu 16900484 kişidir.

# %% [markdown]
# # Problem 8

# %% [markdown]
# Buradaki işlemlerimizin tamamı stringler içindir. Aşağıda verilecek olan metodlar için kendinizin örnek yaratması gerekmektedir.
#
# Örneğin `upper` için `string` değişkeni oluştururken` k = ”BAC”` şeklinde oluşturmayınız. Bunun yerine k değişkenini `k = "bac`" şeklinde oluşturmanız `upper` metodundaki değişimi görebilmeniz için daha iyi olacaktır.
#
# Bütün metodlardaki değişimin gözle görülür şekilde değişimi beklenmektedir.
#
#
# 1- capitalize(), lower(), upper(), swapcase(), title(), replace()
#
# 2- endswith(), startswith(), find(), index(), count()
#
# 3- split(), strip(), join(), islower(), isalpha(), isdigit()
#
#
# Yukarıdaki `string` metodlarındaki değişimleri görebildiğimiz bir program yazınız.

# %%
# 8. problemimiz için kodlarını buraya yazabilirsin.

String = "Bu yaz YetGen Ekibi İle Python öğreniyoruz"
a = String.upper() 
b = String.capitalize()

print(String, "Upper sonrası\n", a)
print(String , "Capitalize sonrası\n" , b)

c = a.lower() 

print(a , "Lower sonrası\n" , c)

d = String.swapcase()

print(String , "Swapcase sonrası\n" , d)

e = String.title()

print(String , "Title sonrası\n" , e)

f = String.replace("Python","Programlama")

print(String, "\n Replace ile Python yerine Programlama ifadesi geldikten sonra\n" , f)

g = String.endswith("öğreniyoruz")

print(String , "Endswith sonrası\n", g)

h = String.startswith("İlk")

print(String, "Startswith sonrası\n" , h)

i = String.find("Python")

print(String , "Find sonrası\n" , i)

ı = String.index("Python")

print(String,"Index sonrası\n", ı)

j = String.count("a")

print(String , "Count sonrası\n" , j)

k = String.split()

print(String, "Split sonrası\n", k)

l = String.strip()

print(String , "Strip sonrası\n" , l)

print("Joint Sonrası\n" , "&".join(k))

m = String.islower()

print(String , "Islower sonrası\n" , m)

n = String.isalpha()

print(String, "Isalpha Sonrası\n" , n)

o = String.isdigit

print(String , "Isdigit sonrası\n" , o)

p = String.lower().islower()

print(String, "Lower ve Islower Sonrası\n", p)
# Out:
# Bu yaz YetGen Ekibi İle Python öğreniyoruz Upper sonrası
#  BU YAZ YETGEN EKIBI İLE PYTHON ÖĞRENIYORUZ
# Bu yaz YetGen Ekibi İle Python öğreniyoruz Capitalize sonrası
#  Bu yaz yetgen ekibi i̇le python öğreniyoruz
# BU YAZ YETGEN EKIBI İLE PYTHON ÖĞRENIYORUZ Lower sonrası
#  bu yaz yetgen ekibi i̇le python öğreniyoruz
# Bu yaz YetGen Ekibi İle Python öğreniyoruz Swapcase sonrası
#  bU YAZ yETgEN eKIBI i̇LE pYTHON ÖĞRENIYORUZ
# Bu yaz YetGen Ekibi İle Python öğreniyoruz Title sonrası
#  Bu Yaz Yetgen Ekibi İle Python Öğreniyoruz
# Bu yaz YetGen Ekibi İle Python öğreniyoruz
#  Replace ile Python yerine Programlama ifadesi geldikten sonra
#  Bu yaz YetGen Ekibi İle Programlama öğreniyoruz
# Bu yaz YetGen Ekibi İle Python öğreniyoruz Endswith sonrası
#  True
# Bu yaz YetGen Ekibi İle Python öğreniyoruz Startswith sonrası
#  False
# Bu yaz YetGen Ekibi İle Python öğreniyoruz Find sonrası
#  24
# Bu yaz YetGen Ekibi İle Python öğreniyoruz Index sonrası
#  24
# ...

# %% [markdown]
# [Ek String Metodları ](https://)https://www.w3schools.com/python/python_ref_string.asp
