# %% [markdown]
# # Problem 1

# %% [markdown]
# ![compound.png](data:image/png;base64,...)

# %% [markdown]
# Yukarıda bileşik faizin hesaplanması ve bu hesaplamaya ait elementlerin açıklamaları verilmiştir.
#
# Kullanıcıdan ilk olarak ad, soyad, yaş ve meslek bilgilerini input (girdi) olarak alınız. Daha sonra principal amount (ana para), rate (faiz oranı) ve time (zamanı yıl olarak) kullanıcıdan input (girdi) alarak bunun sonucunda bileşik faizi hesaplayınız.
#
# Son olarak kullanıcıya:
#
# `“Merhaba A (isim) B (soyad), C (yaşındasınız) ve D mesleğini yapmaktasınız. P (ana para) TL’nin R (faiz oranı) oranı ile  T (yıllık)  bileşik faizi C (bileşik faizi miktarı)’dir” `
#
# Şeklinde bir çıktı veren bir program yazınız.

# %%
# 1. problemimiz için kodlarını buraya yazabilirsin.

A = input("İsminizi Giriniz ")
B = input("Soyadınızı Giriniz ")
C = input("Yaşınızı Giriniz ")
D = input("Mesleğinizi Giriniz ")
P = input("Ana paranızı Giriniz  TL ")
R = input("Faiz oranını Giriniz ")
T = input("Zamanı Giriniz ")
denklem = P*(1 + R/100)
c = pow(denklem,T)

# output = "Merhaba {} {}".format(A,B) + "{} yaşındasınız".format(C) + " {} mesleğini yapmaktasınız.".format(D) + "{} TL’nin".format(P) + "{} oranı ile".format(R) + T "’dir"

# print(output)
print(("Merhaba" "A" "B" , "C" "yaşındasınız" "ve" "D" "mesleğini yapmaktasınız." "P" "TL’nin" "R" "oranı ile" "T" "bileşik faizi" "c" "bileşik faizi miktarı’dir"))
# Out:
# İsminizi Giriniz feyza
# Soyadınızı Giriniz atabey
# Yaşınızı Giriniz 22
# Mesleğinizi Giriniz öğrenci
# Ana paranızı Giriniz  TL 40000
# Faiz oranını Giriniz 20
# Zamanı Giriniz 20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-387e52bf2dd7> in <module>()
#       8 R = input("Faiz oranını Giriniz ")
#       9 T = input("Zamanı Giriniz ")
# ---> 10 denklem = P*(1 + R/100)
#      11 c = pow(denklem,T)
#      12
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
# 1. problemimiz için kodlarını buraya yazabilirsin.

İsim = input ("Adınız Nedir?")
Soy_isim = input ("Soy isminiz nedir?")
yas = input ("Yaşınız nedir?")
meslek= input ("Mesleğiniz nedir?")


p= input("Ana parayı giriniz: ")
r= input ("Faiz oranı: ")
t = input ("YBF:")
a= p(1+r/100)**t
c= a-p
print (a)
print (c)
print (“Merhaba A (isim) B (soyad), C (yaşındasınız) ve D mesleğini yapmaktasınız. P (ana para) TL’nin R (faiz oranı) oranı ile T (yıllık) bileşik faizi C (bileşik faizi miktarı)’dir”)
print("Merhaba {}. {} yaşındasın".format(isim,yas))
# Out:
#   File "<ipython-input-5-12e5d872a442>", line 16
#     print (“Merhaba A (isim) B (soyad), C (yaşındasınız) ve D mesleğini yapmaktasınız. P (ana para) TL’nin R (faiz oranı) oranı ile T (yıllık) bileşik faizi C (bileşik faizi miktarı)’dir”)
#                   ^
# SyntaxError: invalid character in identifier

# %%
A = input("İsminizi Giriniz ")
B = input("Soyadınızı Giriniz ")
C = input("Yaşınızı Giriniz ")
D = input( "Mesleğinizi Giriniz ")
P = float (input("Ana paranızı Giriniz TL "))
R = float (input("Faiz oranını Giriniz "))
T = float (input("Zamanı Giriniz "))
c = P * (1 + R/100)**T
print("Merhaba {} {},  {} yaşındasınız ve {} mesleğini yapmaktasınız. {} TL'nin {} oranı ile {} bileşik faizi {}'dir ".format(A,B,C,D,P,R,T,c))

# %% [markdown]
# # Problem 2

# %% [markdown]
# ![silindir-koni-hacim.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Kullanıcıdan taban yarıçapı ve yükseklik bilgisini alarak silindirin hacmini ve bundan yola çıkarak da koninin hacmini hesaplayınız. Pi sayısını 3.14 olarak sabit giriniz. Daha sonra yukarıdaki problemde olduğu gibi kullanıcıya bilgi veren bir program yazınız.
#
# Örnek:
#
# `”5 cm yarıçaplı 12 cm yüksekliğindeki silindirin hacmi X ve koninin hacmi Y dir.” `
#
# Şeklinde.

# %%
# 2. problemimiz için kodlarını buraya yazabilirsin.

R_silindir = input("Silindirin yarıçapını giriniz ")
H_silindir = input("Silindirin yüksekliğini giriniz ")

H_koni = input("Koninin yüksekliğini giriniz ")
R_koni = input("Koninin yarıçapını giriniz ")

pi = 3.14

V_silindir = int(pi)*int(R_silindir)*int(H_silindir)
V_koni = 1/3*int(pi)*int(R_koni)**2*int(H_koni)

print( "{} ".format(R_koni) + "yarıçaplı " "{}".format(H_koni) + " yüksekliğindeki koninin hacmi" + " {}".format(V_koni) )
# Out:
# Silindirin yarıçapını giriniz 2
# Silindirin yüksekliğini giriniz 2
# Koninin yüksekliğini giriniz 2
# Koninin yarıçapını giriniz 2
# 2 yarıçaplı 2 yüksekliğindeki koninin hacmi 8.0

# %%
R_silindir = float (input("Silindirin yarıçapını giriniz "))
H_silindir = float(input("Silindirin yüksekliğini giriniz "))

H_koni = float(input("Koninin yüksekliğini giriniz "))
R_koni = float(input("Koninin yarıçapını giriniz "))

# %% [markdown]
# # Problem 3

# %% [markdown]
# Kullanıcıdan 2 adet sayı alınız. Geçici (temp) bir değişken yardımı ile bu sayıları birbirleri ile değiştirin bir program yazınız.
#
# Örnek: a = 3, b = 5 işlemden sonra **a = 5, b = 3**.

# %%
# 3. problemimiz için kodlarını buraya yazabilirsin.

a = input("Bir sayı giriniz ")
b = input("Bir sayı giriniz ")

temp = a
a = b
b = temp

print(a)
print(b)
